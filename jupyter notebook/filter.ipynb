# %%
import pandas as pd

# %%
df = pd.read_excel('Payment.xlsx')

# %%
df
# Out:
#              Claim status                       (All)  \
# 0                     NaN                         NaN
# 1              Row Labels  Count of Paid Amount - Dec
# 2   Medicaid / Cal-Optima                         853
# 3        Other Commercial                          24
# 4                  Kaiser                           8
# 5       United Healthcare                          13
# 6                   Aetna                           3
# 7                    BCBS                           5
# 8                   Cigna                           1
# 9     Medicaid / Medi-Cal                           3
# 10                 Humana                         NaN
# 11              uninsured                         NaN
# 12                Tricare                           3
# 13     Medicare Advantage                         NaN
# 14     Medicaid / LA Care                         NaN
# 15           No Insurance                         NaN
# ...
