# %%
import pandas as pd

# %%
data = pd.read_excel("Copy Payment Posting Till date_for automation.xlsx")

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data
# Out:
#        Sl_no AR_Category status GK_order_ID_or_AMD_Chart   Accession  \
# 0          1      Old AR   Open                    262401  AENC-KKHS
# 1          2      Old AR   Open                    310586  AEAA-ARCY
# 2          3      Old AR   Open                    244571  FNER-REFY
# 3          4      Old AR   Open                    323005  VFRU-HQAS
# 4          5      Old AR   Open                    314537  TCKX-QHGP
# ...      ...         ...    ...                       ...        ...
# 29238  29239      AMD AR   Open                       113        NaN
# 29239  29240      AMD AR   Open                       114        NaN
# 29240  29241      AMD AR   Open                       115        NaN
# 29241  29242      AMD AR   Open                       116        NaN
# 29242  29243      AMD AR   Open                       119        NaN
#
#       Patient_id  Claim_id_or_AMD_Visit             Patient_Name        DOB  \
# ...

# %%
# Check for the exact column names to ensure we're targeting the correct ones
column_names = data.columns.tolist()

# Identify the columns that closely match "Date_of_Service" and "last_billed_date"
date_of_service_column = [col for col in column_names if "Date_of_Service" in col]
last_billed_date_column = [col for col in column_names if "last_billed_date" in col]

date_of_service_column, last_billed_date_column





# Convert the 'Date_of_Service' column to datetime format
data['Date_of_Service'] = pd.to_datetime(data['Date_of_Service'], errors='coerce')

# Check the conversion by displaying the data types of columns
data.dtypes['Date_of_Service']
# Out:
# dtype('<M8[ns]')

# %%
column_names = data.columns.tolist()

# %%
column_names
# Out:
# ['Sl_no',
#  'AR_Category',
#  'status',
#  'GK_order_ID_or_AMD_Chart ',
#  'Accession',
#  'Patient_id',
#  'Claim_id_or_AMD_Visit ',
#  'Patient_Name',
#  'DOB',
#  'Payer_Family',
#  'Payer',
#  'Date_of_Service',
#  'AMD_CPT_Codes',
#  'Billed_amt',
#  'Last_Billed_Date',
#  'Date_x',
#  'Aging_Days_from_DOS',
#  'Aging_Bucket_from_DOS',
#  'TFL_Bucket',
#  ' Paid_Amount  ',
#  'Balance',
#  'check_no',
#  'Billed_Status',
#  'Pay_status',
#  'Paid_date',
#  'Claim_status',
#  'AR_Status',
#  'Response',
#  'Denial_Category',
#  'Medi_Cal_Claims_Remark',
#  'GK_Location',
#  'Report',
#  'Billed_Amount',
#  'Allowed_Amount',
#  'Paid_Amount_DEC',
#  'Adjustment_Amount',
#  'Denied',
#  'Remark_Code',
#  'Check_Amount',
#  'File_name_or_Remarks',
#  'Page',
#  'comments',
#  'names']

# %%
date_of_service_column = [col for col in column_names if "Date_of_Service" in col]
last_billed_date_column = [col for col in column_names if "last_billed_date" in col]

# %%
print(date_of_service_column)
# Out:
# ['Date_of_Service']

# %%
df =  data

# %%
# Convert the 'Date_of_Service' column to datetime format
data['Date_of_Service'] = pd.to_datetime(data['Date_of_Service'], errors='coerce')

# Check the conversion by displaying the data types of columns
data.dtypes['Date_of_Service']
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29243 entries, 0 to 29242
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl_no                      29243 non-null  int64
#  1   AR_Category                29243 non-null  object
#  2   status                     29243 non-null  object
#  3   GK_order_ID_or_AMD_Chart   29243 non-null  object
#  4   Accession                  29084 non-null  object
#  5   Patient_id                 24450 non-null  object
#  6   Claim_id_or_AMD_Visit      24153 non-null  float64
#  7   Patient_Name               29243 non-null  object
#  8   DOB                        29088 non-null  datetime64[ns]
#  9   Payer_Family               29243 non-null  object
#  10  Payer                      29243 non-null  object
#  11  Date_of_Service            29222 non-null  datetime64[ns]
#  12  AMD_CPT_Codes              130 non-null    float64
# ...

# %%
# Convert the 'Last_Billed_Date' column to datetime format
df['Last_Billed_Date'] = pd.to_datetime(df['Last_Billed_Date'], errors='coerce')

# Check the conversion by displaying the data types of columns
df.dtypes['Last_Billed_Date']




df.columns = df.columns.str.strip()

# Now, convert 'GK_order_ID_or_AMD_Chart' to integers, turning errors into NaN
df['GK_order_ID_or_AMD_Chart'] = pd.to_numeric(df['GK_order_ID_or_AMD_Chart'], errors='coerce')

# Replace NaN values with 0
df['GK_order_ID_or_AMD_Chart'] = df['GK_order_ID_or_AMD_Chart'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29243 entries, 0 to 29242
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sl_no                     29243 non-null  int64
#  1   AR_Category               29243 non-null  object
#  2   status                    29243 non-null  object
#  3   GK_order_ID_or_AMD_Chart  29243 non-null  int64
#  4   Accession                 29084 non-null  object
#  5   Patient_id                24450 non-null  object
#  6   Claim_id_or_AMD_Visit     24153 non-null  float64
#  7   Patient_Name              29243 non-null  object
#  8   DOB                       29088 non-null  datetime64[ns]
#  9   Payer_Family              29243 non-null  object
#  10  Payer                     29243 non-null  object
#  11  Date_of_Service           29222 non-null  datetime64[ns]
#  12  AMD_CPT_Codes             130 non-null    float64
# ...

# %%
# Assuming 'df' is your DataFrame
# Convert 'Patient_id' to numeric, turning non-numeric entries into NaN
df['Patient_id'] = pd.to_numeric(df['Patient_id'], errors='coerce')

# Optional: If you want NaN values to be replaced with 0
df['Patient_id'] = df['Patient_id'].fillna(0).astype(int)

# If you prefer to keep NaN values (indicating missing data) while still having the column in an integer format
# df['Patient_id'] = df['Patient_id'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29243 entries, 0 to 29242
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sl_no                     29243 non-null  int64
#  1   AR_Category               29243 non-null  object
#  2   status                    29243 non-null  object
#  3   GK_order_ID_or_AMD_Chart  29243 non-null  int64
#  4   Accession                 29084 non-null  object
#  5   Patient_id                29243 non-null  int64
#  6   Claim_id_or_AMD_Visit     24153 non-null  float64
#  7   Patient_Name              29243 non-null  object
#  8   DOB                       29088 non-null  datetime64[ns]
#  9   Payer_Family              29243 non-null  object
#  10  Payer                     29243 non-null  object
#  11  Date_of_Service           29222 non-null  datetime64[ns]
#  12  AMD_CPT_Codes             130 non-null    float64
# ...

# %%
# Assuming 'df' is your DataFrame
# Convert 'Claim_id_or_AMD_Visit' to numeric, turning errors (non-numeric entries) into NaN
df['Claim_id_or_AMD_Visit'] = pd.to_numeric(df['Claim_id_or_AMD_Visit'], errors='coerce')

# If you wish to replace NaN values with 0 and convert to standard integer
df['Claim_id_or_AMD_Visit'] = df['Claim_id_or_AMD_Visit'].fillna(0).astype(int)

# If you prefer to keep NaN values while still converting to an integer format (nullable integer type)
# df['Claim_id_or_AMD_Visit'] = df['Claim_id_or_AMD_Visit'].astype('Int64')

# %%
# Convert 'Claim_id_or_AMD_Visit' to numeric, coercing errors to NaN
df['Claim_id_or_AMD_Visit'] = pd.to_numeric(df['Claim_id_or_AMD_Visit'], errors='coerce')

# Optional: Replace NaN values with 0
df['Claim_id_or_AMD_Visit'] = df['Claim_id_or_AMD_Visit'].fillna(0).astype(int)

# If you prefer to keep NaN values (to indicate missing data) while still converting to an integer format:
# df['Claim_id_or_AMD_Visit'] = df['Claim_id_or_AMD_Visit'].astype('Int64')

# %%
# Convert 'Claim_id_or_AMD_Visit' to numeric, coercing non-numeric values to NaN
df['Claim_id_or_AMD_Visit'] = pd.to_numeric(df['Claim_id_or_AMD_Visit'], errors='coerce')

# Replace NaN values with 0, then convert to integer
df['Claim_id_or_AMD_Visit'] = df['Claim_id_or_AMD_Visit'].fillna(0).astype(int)

# %%
df2=df

# %%
# Assuming 'df' is your DataFrame
# Convert 'Billed_amt' to numeric, coercing errors (non-numeric entries) into NaN
df2['Billed_amt'] = pd.to_numeric(df['Billed_amt'], errors='coerce')

# Replace NaN values with 0 and convert to integer
df2['Billed_amt'] = df2['Billed_amt'].fillna(0).astype(int)

# %%
# Assuming 'df' is your DataFrame
# Convert 'Paid_Amount' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Paid_Amount'] = pd.to_numeric(df2['Paid_Amount'], errors='coerce')

# %%
# Assuming 'df' is your DataFrame
# Convert 'Balance' to numeric, turning any non-numeric entries into NaN
df2['Balance'] = pd.to_numeric(df2['Balance'], errors='coerce')

# Replace NaN values with 0, then convert to integer
df2['Balance'] = df2['Balance'].fillna(0).astype(int)

# %%
# Assuming 'df' is your DataFrame
# Convert 'Billed_Amount' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Billed_Amount'] = pd.to_numeric(df2['Billed_Amount'], errors='coerce')

# %%
# Assuming 'df' is your DataFrame
# Convert 'Allowed_Amount' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Allowed_Amount'] = pd.to_numeric(df2['Allowed_Amount'], errors='coerce')

# %%
# Assuming 'df' is your DataFrame
# Convert 'Paid_Amount_DEC' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Paid_Amount_DEC'] = pd.to_numeric(df2['Paid_Amount_DEC'], errors='coerce')

# %%
# Assuming 'df' is your DataFrame
# Convert 'Remark_Code' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Remark_Code'] = pd.to_numeric(df2['Remark_Code'], errors='coerce')

# %%
# Assuming 'df' is your DataFrame
# Convert 'Check_Amount' to numeric (float), coercing errors (non-numeric entries) into NaN
df2['Check_Amount'] = pd.to_numeric(df2['Check_Amount'], errors='coerce')

# %%
df2['File_name_or_Remarks'] = pd.to_numeric(df2['Check_Amount'], errors='coerce')

# %%
df2['Page'] = pd.to_numeric(df2['Page'], errors='coerce')

# %%
df2['comments'] = pd.to_numeric(df2['comments'], errors='coerce')

# %%
# Fill NaN values with 0 and convert the column to integer
df2['AMD_CPT_Codes'] = df2['AMD_CPT_Codes'].fillna(0).astype(int)

# Display the first few rows to confirm the changes
df2[['AMD_CPT_Codes']].head()
# Out:
#    AMD_CPT_Codes
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df2['AMD_CPT_Codes'] = df['AMD_CPT_Codes'].astype(int)

# %%
# Count null values in each column
df2.isnull().sum()
# Out:
# Sl_no                           0
# AR_Category                     0
# status                          0
# GK_order_ID_or_AMD_Chart        0
# Accession                     159
# Patient_id                      0
# Claim_id_or_AMD_Visit           0
# Patient_Name                    0
# DOB                           155
# Payer_Family                    0
# Payer                           0
# Date_of_Service                21
# AMD_CPT_Codes                   0
# Billed_amt                      0
# Last_Billed_Date             4499
# Date_x                          0
# Aging_Days_from_DOS             0
# Aging_Bucket_from_DOS           0
# TFL_Bucket                      0
# Paid_Amount                 29243
# Balance                         0
# check_no                    18697
# Billed_Status                   0
# Pay_status                  17890
# Paid_date                   17884
# Claim_status                    0
# AR_Status                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29243 entries, 0 to 29242
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sl_no                     29243 non-null  int64
#  1   AR_Category               29243 non-null  object
#  2   status                    29243 non-null  object
#  3   GK_order_ID_or_AMD_Chart  29243 non-null  int64
#  4   Accession                 29084 non-null  object
#  5   Patient_id                29243 non-null  int64
#  6   Claim_id_or_AMD_Visit     29243 non-null  int64
#  7   Patient_Name              29243 non-null  object
#  8   DOB                       29088 non-null  datetime64[ns]
#  9   Payer_Family              29243 non-null  object
#  10  Payer                     29243 non-null  object
#  11  Date_of_Service           29222 non-null  datetime64[ns]
#  12  AMD_CPT_Codes             29243 non-null  int64
# ...

# %%
df2['Adjustment_Amount'] = pd.to_numeric(df2['Denied'], errors='coerce')

# %%
df2['Denied'] = pd.to_numeric(df2['Adjustment_Amount'], errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29243 entries, 0 to 29242
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sl_no                     29243 non-null  int64
#  1   AR_Category               29243 non-null  object
#  2   status                    29243 non-null  object
#  3   GK_order_ID_or_AMD_Chart  29243 non-null  int64
#  4   Accession                 29084 non-null  object
#  5   Patient_id                29243 non-null  int64
#  6   Claim_id_or_AMD_Visit     29243 non-null  int64
#  7   Patient_Name              29243 non-null  object
#  8   DOB                       29088 non-null  datetime64[ns]
#  9   Payer_Family              29243 non-null  object
#  10  Payer                     29243 non-null  object
#  11  Date_of_Service           29222 non-null  datetime64[ns]
#  12  AMD_CPT_Codes             29243 non-null  int64
# ...

# %%
df2.info()

# %%
# it will save the code related to updated code
df2.to_excel('cleaned_data.xlsx', index=False)  # Similar to CSV, index=False avoids saving the index
