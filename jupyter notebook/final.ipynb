# %%
import pandas as pd

# %%
data = pd.read_excel('paymet.xlsx')

# %%
data
# Out:
#          Sl# AR Category status  GK order ID# / AMD Chart #  Accession  \
# 0          1      Old AR   Open                      262401  AENC-KKHS
# 1          2      Old AR   Open                      310586  AEAA-ARCY
# 2          3      Old AR   Open                      244571  FNER-REFY
# 3          4      Old AR   Open                      323005  VFRU-HQAS
# 4          5      Old AR   Open                      314537  TCKX-QHGP
# ...      ...         ...    ...                         ...        ...
# 12385  12386      Old AR   Open                      304777  FCTP-XYKV
# 12386  12387      Old AR   Open                      247210  HHQH-AAGH
# 12387  12388      Old AR   Open                      331494  TRTS-YGHA
# 12388  12389      Old AR   Open                      324043  CTXV-KKRP
# 12389  12390      Old AR   Open                      320341  WUST-ERUG
#
#       Patient_id  Claim_id / AMD Visit #            Patient Name        DOB  \
# ...

# %%
filtered_data = data[data['Payer Family'] == 'Medicaid / Medi-Cal']

# %%
filtered_data.to_excel('filteredd_data.xlsx', index=False)
